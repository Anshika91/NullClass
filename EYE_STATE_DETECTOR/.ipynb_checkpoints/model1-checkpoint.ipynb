# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import cv2
import os
from tkinter import filedialog
get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt


from keras.utils import plot_model
from keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from keras.layers import BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential

# %%
open_eyes_path = 'train/open_eyes'
close_eyes_path = 'train/close_eyes'

# %%
open_eyes = []
for filename in os.listdir(open_eyes_path):
    image_path = os.path.join(open_eyes_path, filename)
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read image as grayscale
    resized_image = cv2.resize(image, (24, 24))  # Resize image to 24x24 pixels
    open_eyes.append(resized_image)

# %%
close_eyes = []
for filename in os.listdir(close_eyes_path):
    image_path = os.path.join(close_eyes_path, filename)
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read image as grayscale
    resized_image = cv2.resize(image, (24, 24))  # Resize image to 24x24 pixels
    close_eyes.append(resized_image)

# %%
open_eyes_labels = [1] * len(open_eyes)  # Label 1 for open eyes
close_eyes_labels = [0] * len(close_eyes)  # Label 0 for closed eyes

# %%
images = np.concatenate((open_eyes, close_eyes), axis=0)
labels = np.concatenate((open_eyes_labels, close_eyes_labels), axis=0)

# %%
images = np.array(images) / 255.0
images = images.reshape(-1, 24, 24, 1)

# %%
labels = tf.keras.utils.to_categorical(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(24, 24, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Assuming binary classification (open or closed)
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 199/199 [==============================] - 7s 23ms/step - loss: 0.4428 - accuracy: 0.8111 - val_loss: 0.2728 - val_accuracy: 0.9158
# Epoch 2/10
# 199/199 [==============================] - 4s 20ms/step - loss: 0.1863 - accuracy: 0.9348 - val_loss: 0.1706 - val_accuracy: 0.9390
# Epoch 3/10
# 199/199 [==============================] - 5s 23ms/step - loss: 0.1295 - accuracy: 0.9508 - val_loss: 0.1313 - val_accuracy: 0.9510
# Epoch 4/10
# 199/199 [==============================] - 7s 34ms/step - loss: 0.1041 - accuracy: 0.9612 - val_loss: 0.1220 - val_accuracy: 0.9535
# Epoch 5/10
# 199/199 [==============================] - 4s 21ms/step - loss: 0.0968 - accuracy: 0.9639 - val_loss: 0.1455 - val_accuracy: 0.9453
# Epoch 6/10
# 199/199 [==============================] - 7s 36ms/step - loss: 0.0796 - accuracy: 0.9700 - val_loss: 0.0960 - val_accuracy: 0.9623
# Epoch 7/10
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0902 - accuracy: 0.9692
# Test loss: 0.0901925265789032
# Test accuracy: 0.9692017436027527

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
open_eyes_path = r"train\open_eyes"
Closed_eyes_path = r"train\close_eyes"

open_eyes_images = []
for filename in os.listdir(open_eyes_path):
    image_path = os.path.join(open_eyes_path, filename)
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, (24, 24))
    open_eyes_images.append(resized_image)

Closed_eyes_images = []
for filename in os.listdir(Closed_eyes_path):
    image_path = os.path.join(Closed_eyes_path, filename)
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, (24, 24))
    Closed_eyes_images.append(resized_image)

# %%
open_eyes_images = np.array(open_eyes_images) / 255.0
open_eyes_images = open_eyes_images.reshape(-1, 24, 24, 1)
print(len(open_eyes_images))
# Out:
# 1657

# %%
predictions = model.predict(open_eyes_images)
# Out:
# 52/52 [==============================] - 1s 7ms/step

# %%
Closed_eyes_images = np.array(Closed_eyes_images) / 255.0
Closed_eyes_images = Closed_eyes_images.reshape(-1, 24, 24, 1)
print(len(Closed_eyes_images))
# Out:
# 6298

# %%
predictions = model.predict(Closed_eyes_images)
# Out:
# 197/197 [==============================] - 2s 9ms/step

# %%
model.save("eye_detection_model.h5")
